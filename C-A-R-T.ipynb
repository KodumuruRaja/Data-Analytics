# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_excel("C:/Users/raja asus/Desktop/Data Analytics/CART.xlsx")
data
# Out:
#     RID          age  income student credit_rating buys_computer
# 0     1        youth    high      no          fair            no
# 1     2        youth    high      no     excellent            no
# 2     3  middle_aged    high      no          fair           yes
# 3     4       senior  medium      no          fair           yes
# 4     5       senior     low     yes          fair           yes
# 5     6       senior     low     yes     excellent            no
# 6     7  middle_aged     low     yes     excellent           yes
# 7     8        youth  medium      no          fair            no
# 8     9        youth     low     yes          fair           yes
# 9    10       senior  medium     yes          fair           yes
# 10   11        youth  medium     yes     excellent           yes
# 11   12  middle_aged  medium      no     excellent           yes
# 12   13  middle_aged    high     yes          fair           yes
# ...

# %% [markdown]
# ### Data Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
age1=LabelEncoder()
data['age']=age1.fit_transform(data['age'])
data
# Out:
#     RID  age  income student credit_rating buys_computer
# 0     1    2    high      no          fair            no
# 1     2    2    high      no     excellent            no
# 2     3    0    high      no          fair           yes
# 3     4    1  medium      no          fair           yes
# 4     5    1     low     yes          fair           yes
# 5     6    1     low     yes     excellent            no
# 6     7    0     low     yes     excellent           yes
# 7     8    2  medium      no          fair            no
# 8     9    2     low     yes          fair           yes
# 9    10    1  medium     yes          fair           yes
# 10   11    2  medium     yes     excellent           yes
# 11   12    0  medium      no     excellent           yes
# 12   13    0    high     yes          fair           yes
# 13   14    1  medium      no     excellent            no

# %%
income1=LabelEncoder()
data['income']=income1.fit_transform(data['income'])
data
# Out:
#     RID  age  income student credit_rating buys_computer
# 0     1    2       0      no          fair            no
# 1     2    2       0      no     excellent            no
# 2     3    0       0      no          fair           yes
# 3     4    1       2      no          fair           yes
# 4     5    1       1     yes          fair           yes
# 5     6    1       1     yes     excellent            no
# 6     7    0       1     yes     excellent           yes
# 7     8    2       2      no          fair            no
# 8     9    2       1     yes          fair           yes
# 9    10    1       2     yes          fair           yes
# 10   11    2       2     yes     excellent           yes
# 11   12    0       2      no     excellent           yes
# 12   13    0       0     yes          fair           yes
# 13   14    1       2      no     excellent            no

# %%
student1=LabelEncoder()
data['student']=student1.fit_transform(data['student'])
data
# Out:
#     RID  age  income  student credit_rating buys_computer
# 0     1    2       0        0          fair            no
# 1     2    2       0        0     excellent            no
# 2     3    0       0        0          fair           yes
# 3     4    1       2        0          fair           yes
# 4     5    1       1        1          fair           yes
# 5     6    1       1        1     excellent            no
# 6     7    0       1        1     excellent           yes
# 7     8    2       2        0          fair            no
# 8     9    2       1        1          fair           yes
# 9    10    1       2        1          fair           yes
# 10   11    2       2        1     excellent           yes
# 11   12    0       2        0     excellent           yes
# 12   13    0       0        1          fair           yes
# 13   14    1       2        0     excellent            no

# %%
credit_rating1=LabelEncoder()
data['credit_rating']=credit_rating1.fit_transform(data['credit_rating'])
data
# Out:
#     RID  age  income  student  credit_rating buys_computer
# 0     1    2       0        0              1            no
# 1     2    2       0        0              0            no
# 2     3    0       0        0              1           yes
# 3     4    1       2        0              1           yes
# 4     5    1       1        1              1           yes
# 5     6    1       1        1              0            no
# 6     7    0       1        1              0           yes
# 7     8    2       2        0              1            no
# 8     9    2       1        1              1           yes
# 9    10    1       2        1              1           yes
# 10   11    2       2        1              0           yes
# 11   12    0       2        0              0           yes
# 12   13    0       0        1              1           yes
# 13   14    1       2        0              0            no

# %%
buys_computer1=LabelEncoder()
data['buys_computer']=buys_computer1.fit_transform(data['buys_computer'])
data
# Out:
#     RID  age  income  student  credit_rating  buys_computer
# 0     1    2       0        0              1              0
# 1     2    2       0        0              0              0
# 2     3    0       0        0              1              1
# 3     4    1       2        0              1              1
# 4     5    1       1        1              1              1
# 5     6    1       1        1              0              0
# 6     7    0       1        1              0              1
# 7     8    2       2        0              1              0
# 8     9    2       1        1              1              1
# 9    10    1       2        1              1              1
# 10   11    2       2        1              0              1
# 11   12    0       2        0              0              1
# 12   13    0       0        1              1              1
# 13   14    1       2        0              0              0

# %%
data.drop(['RID'],axis=1,inplace=True)

# %%
data
# Out:
#     age  income  student  credit_rating  buys_computer
# 0     2       0        0              1              0
# 1     2       0        0              0              0
# 2     0       0        0              1              1
# 3     1       2        0              1              1
# 4     1       1        1              1              1
# 5     1       1        1              0              0
# 6     0       1        1              0              1
# 7     2       2        0              1              0
# 8     2       1        1              1              1
# 9     1       2        1              1              1
# 10    2       2        1              0              1
# 11    0       2        0              0              1
# 12    0       0        1              1              1
# 13    1       2        0              0              0

# %%
x=data[['age','income','student','credit_rating']]
y=data[['buys_computer']]

# %%
x
# Out:
#     age  income  student  credit_rating
# 0     2       0        0              1
# 1     2       0        0              0
# 2     0       0        0              1
# 3     1       2        0              1
# 4     1       1        1              1
# 5     1       1        1              0
# 6     0       1        1              0
# 7     2       2        0              1
# 8     2       1        1              1
# 9     1       2        1              1
# 10    2       2        1              0
# 11    0       2        0              0
# 12    0       0        1              1
# 13    1       2        0              0

# %%
y
# Out:
#     buys_computer
# 0               0
# 1               0
# 2               1
# 3               1
# 4               1
# 5               0
# 6               1
# 7               0
# 8               1
# 9               1
# 10              1
# 11              1
# 12              1
# 13              0

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()
model=clf.fit(x,y)
model
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Decision Tree Visualization before training & testing the model

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus

# %%
feature_cols=['age','income','student','credit_rating']

# %%
import os
os.environ['PATH'] = os.environ['PATH']+';'+os.environ['CONDA_PREFIX']+r"\Library\bin\graphviz"

# %%
data1=StringIO()
export_graphviz(model,out_file=data1,filled=True,rounded=True,special_characters=True,feature_names=feature_cols,class_names=['0','1'])
graph=pydotplus.graph_from_dot_data(data1.getvalue())
graph.write_png('buys_computer.png')
# Out:
# True

# %%
Image(graph.create_png())

# %% [markdown]
# ### Training & Testing,Decision Tree Classifier

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=32)

# %%
clf=DecisionTreeClassifier()
model=clf.fit(x_train,y_train)
model
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6666666666666666

# %% [markdown]
# ### Decision Tree Visualization after training & testing

# %%
data1=StringIO()
export_graphviz(model,out_file=data1,filled=True,rounded=True,special_characters=True,feature_names=feature_cols,class_names=['0','1'])
graph=pydotplus.graph_from_dot_data(data1.getvalue())
graph.write_png('buys_computer.png')
# Out:
# True

# %%
Image(graph.create_png())
